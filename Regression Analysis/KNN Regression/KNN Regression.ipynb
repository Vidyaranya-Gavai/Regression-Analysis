# %%
# Importing libraries and dataset
import numpy as np
import pandas as pd

data = pd.read_csv('F:\MachineHack\Regression Analysis\KNN Regression\Profit.csv')

# %%
data
# Out:
#      Marketing Spend     Profit
# 0          471784.10  192261.83
# 1          443898.53  191792.06
# 2          407934.54  191050.39
# 3          383199.62  182901.99
# 4          366168.42  166187.94
# ..               ...        ...
# 195          1853.93   64876.08
# 196        297064.46   49440.75
# 197        210975.00   42509.73
# 198        210975.00   35623.41
# 199         45123.06   14631.40
#
# [200 rows x 2 columns]

# %%
# Defining input and output features

x = data.iloc[:, :-1].values
y = data.iloc[:, -1].values
print(x.shape, y.shape)
# Out:
# (200, 1) (200,)

# %%
# Defining training and testing datasets

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = 0)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (180, 1)
# (20, 1)
# (180,)
# (20,)

# %%
# Initializing KNN Regression model

from sklearn.neighbors import KNeighborsRegressor

reg = KNeighborsRegressor()

# Finding the optimal value of k (Hyperparameter tuning)

from sklearn.model_selection import GridSearchCV

k_range = list(range(1,21))
param_grid = dict(n_neighbors = k_range)
grid = GridSearchCV(reg, param_grid, cv=10, scoring='r2', return_train_score=False, verbose=4)
grid.fit(x_train, y_train)

# Training the model

reg.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [CV 1/10] END ....................n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 2/10] END ....................n_neighbors=1;, score=0.699 total time=   0.0s
# [CV 3/10] END ....................n_neighbors=1;, score=0.811 total time=   0.0s
# [CV 4/10] END ....................n_neighbors=1;, score=0.998 total time=   0.0s
# [CV 5/10] END ....................n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 6/10] END ....................n_neighbors=1;, score=0.830 total time=   0.0s
# [CV 7/10] END ....................n_neighbors=1;, score=0.827 total time=   0.0s
# [CV 8/10] END ....................n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 9/10] END ...................n_neighbors=1;, score=-0.158 total time=   0.0s
# [CV 10/10] END ...................n_neighbors=1;, score=1.000 total time=   0.0s
# [CV 1/10] END ....................n_neighbors=2;, score=1.000 total time=   0.0s
# ...

# %%
# Making predictions on testing data

y_pred = reg.predict(x_test)

# Comparing the predicted and actual values of profit

pd.DataFrame(data = {'Predicted':y_pred, 'Actual':y_test})
# Out:
#      Predicted     Actual
# 0    94344.440  124266.90
# 1   115607.626  118424.03
# 2   153618.102  155752.60
# 3    73269.318   35673.41
# 4   125799.434  104958.31
# 5    64337.264   97377.84
# 6   160659.848  156991.12
# 7    77074.062   49530.75
# 8   142661.072  141585.52
# 9   187791.030  191000.39
# 10  143177.848  144259.40
# 11  107843.420  107444.34
# 12   97972.366   99887.59
# 13  162509.212  166137.94
# 14   97972.366   99937.59
# 15  153618.102  155752.60
# 16   73727.980   96778.92
# 17   97972.366   99977.59
# 18   90240.760   89949.14
# 19  108090.960  108552.04

# %%
# Evaluating model performance

from sklearn.metrics import mean_squared_error, r2_score
import math

mse = mean_squared_error(y_test, y_pred)
rmse = math.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('MSE = ', mse)
print('RMSE = ', rmse)
print('R-Squared = ', r2)
# Out:
# MSE =  259656199.62330428
# RMSE =  16113.851172928968
# R-Squared =  0.8129821161194329
