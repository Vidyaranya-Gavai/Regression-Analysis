# %%
# importing libraries and dataset

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('F:\MachineHack\Regression Analysis\Polynomial Regression\Experience_Salaries.csv')
data
# Out:
#                  Designation  Experience  Salary
# 0            Sales Executive           1   50000
# 1            Office Asistant           2   55000
# 2          Software Engineer           3   85000
# 3              Sales Manager           4  100000
# 4          Assistant Manager           5  125000
# 5                    HR Head           7  120000
# 6  Technical Project Manager           9  135000
# 7             Senior Manager          10  140000
# 8             Marketing Head          12  120000
# 9                   Director          15  220000

# %%
# Defining input and output features

x = data.iloc[:, 1:-1].values
y = data.iloc[:, -1].values

print(x.shape, y.shape)
# Out:
# (10, 1) (10,)

# %%
# Defining and fitting a polynomial regression model

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly_reg = PolynomialFeatures(degree = 5)
x_poly = poly_reg.fit_transform(x)
lin_reg = LinearRegression()
lin_reg.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
# Visualizing the fitted polynomial regression model

plt.scatter(x, y, color='red')
plt.plot(x, lin_reg.predict(x_poly), color='blue')
plt.title('Exp vs Sal')
plt.xlabel('Exp')
plt.ylabel('Sal')
plt.show()

# %%
# More refined visualization

x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape((len(x_grid), 1))

plt.scatter(x, y, color='red')
plt.plot(x_grid, lin_reg.predict(poly_reg.fit_transform(x_grid)), color='blue')
plt.title('Exp vs Sal')
plt.xlabel('Exp')
plt.ylabel('Sal')
plt.show()

# %%
# Predicting values using linear regression model
#                      vs
# Predicting values using polynomial regression model

lin_reg2 = LinearRegression()
lin_reg2.fit(x, y)

print("Prediction for 3.5(Linear model): ", lin_reg2.predict([[3.5]]))
print("Prediction for 3.5(Polynomial model):",
        lin_reg.predict(poly_reg.fit_transform([[3.5]])))
# Out:
# Prediction for 3.5(Linear model):  [83739.56158664]
# Prediction for 3.5(Polynomial model): [91065.81257016]
